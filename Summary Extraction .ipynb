# %%
import nltk
from newspaper import Article

# %%
def summary_extract(url):
    reg = Article(url)
    reg.download()
    reg.parse()
    reg.download("punkt")
    reg.nlp()
    print("----Author Name--------",str(reg.authors))
    print()
    print("----Publish Date-------=" , reg.publish_date)
    print()
    print("-----------------------------------text-----------------------------------")
    print("text of the article = " , reg.text)
    print()
    print("----------------------Images in articles------------------------------------")
    for i in reg.images:
        a = '\n\t' + i
    print(a)
    print()
    print("__________________________________Summary_______________________________________")
    summ = reg.summary
    print(summ)

# %%
url = "https://www.nytimes.com/2021/10/03/sports/football/brady-bucs-patriots-belichick.html"
summary_extract(url)
# Out:
# ----Author Name-------- ['Ken Belson']
#
# ----Publish Date-------= 2021-10-03 00:00:00
#
# -----------------------------------text-----------------------------------
# text of the article =  Brady looked unsteady for much of the game, overthrowing receivers and settling for field goals instead of touchdowns. Still, when he completed a 28-yard pass to receiver Mike Evans in the first quarter, Brady became the N.F.L.’s career passing leader, surpassing the record of 80,358 yards set last year by Drew Brees, the New Orleans Saints quarterback who retired at the end of the season. Brady now has 80,560 passing yards. He also has the most touchdown passes in N.F.L. history, with 591, having thrown 20 more than Brees.
#
# New England noted the passing yards record on the stadium’s video screens and there was a burst of cheers, but it was otherwise business as usual as fans snapped back into form.
#
# ...

# %% [markdown]
# ### For Multiple Articles

# %%
import nltk
import newspaper
from newspaper import Article

# %%
bbc_news = newspaper.build('https://www.nytimes.com/')

# %%
bbc_news

# %%
a = []
for i in bbc_news.articles:
    print(i.url)
    a.append(i.url)
# Out:
# https://www.nytimes.com/2021/10/03/us/politics/supreme-court-new-term.html
# https://www.nytimes.com/2021/10/03/nyregion/nj-midterms-democrats-infrastructure.html
# https://www.nytimes.com/2021/10/03/us/politics/progressive-democrats-infrastructure-abortion.html
# https://www.nytimes.com/2021/10/03/us/politics/antony-blinken-france-submarine.html
# https://www.nytimes.com/2021/10/03/world/europe/germany-elections-young-voters-greens.html
# https://www.nytimes.com/2021/10/03/us/coronavirus-crisis-alaska.html
# https://www.nytimes.com/live/2021/10/03/world/covid-delta-variant-vaccine?type=styln-live-updates&label=coronavirus updates&index=0
# https://www.nytimes.com/live/2021/10/03/world/covid-delta-variant-vaccine?type=styln-live-updates&label=coronavirus%20updates&index=0#delta-deaths-nursing-homes
# https://www.nytimes.com/live/2021/10/03/world/covid-delta-variant-vaccine?type=styln-live-updates&label=coronavirus%20updates&index=0#merck-covid-pill-vaccine-fauci
# ...

# %%
for j in bbc_news.category_urls():
    print(j)
# Out:
# https://www.nytimes.com/
# https://www.nytimes.com/international
# https://cooking.nytimes.com
# https://cn.nytimes.com
# https://www.nytimes.com
# https://www.nytimes.com/video
# https://nytimes.com
# https://www.nytimes.com/ca

# %%
a = ['https://www.nytimes.com/2021/10/03/us/politics/supreme-court-new-term.html',
 'https://www.nytimes.com/2021/10/03/nyregion/nj-midterms-democrats-infrastructure.html',
 'https://www.nytimes.com/2021/10/03/us/politics/progressive-democrats-infrastructure-abortion.html',
 'https://www.nytimes.com/2021/10/03/us/politics/antony-blinken-france-submarine.html',
 'https://www.nytimes.com/2021/10/03/world/europe/germany-elections-young-voters-greens.html',
 'https://www.nytimes.com/2021/10/03/us/coronavirus-crisis-alaska.html',
 'https://www.nytimes.com/live/2021/10/03/world/covid-delta-variant-vaccine?type=styln-live-updates&label=coronavirus updates&index=0',
 'https://www.nytimes.com/live/2021/10/03/world/covid-delta-variant-vaccine?type=styln-live-updates&label=coronavirus%20updates&index=0#delta-deaths-nursing-homes',
 'https://www.nytimes.com/live/2021/10/03/world/covid-delta-variant-vaccine?type=styln-live-updates&label=coronavir
://www.nytimes.com/2021/10/03/us/politics/supreme-court-new-term.html',
#  'https://www.nytimes.com/2021/10/03/nyregion/nj-midterms-democrats-infrastructure.html',
#  'https://www.nytimes.com/2021/10/03/us/politics/progressive-democrats-infrastructure-abortion.html',
#  'https://www.nytimes.com/2021/10/03/us/politics/antony-blinken-france-submarine.html',
#  'https://www.nytimes.com/2021/10/03/world/europe/germany-elections-young-voters-greens.html',
#  'https://www.nytimes.com/2021/10/03/us/coronavirus-crisis-alaska.html',
#  'https://www.nytimes.com/live/2021/10/03/world/covid-delta-variant-vaccine?type=styln-live-updates&label=coronavirus updates&index=0',
#  'https://www.nytimes.com/live/2021/10/03/world/covid-delta-variant-vaccine?type=styln-live-updates&label=coronavirus%20updates&index=0#delta-deaths-nursing-homes',
# ...

# %%
len(a)
# Out:
# 126

# %%
a = a[:70]
len(a)
# Out:
# 70

# %%
a[0]
# Out:
# 'https://www.nytimes.com/2021/10/03/us/politics/supreme-court-new-term.html'

# %% [markdown]
# #### only one out of len(a)

# %%
# for one link in a 
def summary_extract(url):
    reg = Article(url)
    reg.download()
    reg.parse()
    reg.download("punkt")
    reg.nlp()
    print("----Author Name--------",str(reg.authors))
    print()
    print("----Publish Date-------=" , reg.publish_date)
    print()
    print("-----------------------------------text-----------------------------------")
    print("text of the article = " , reg.text)
    print()
    print("----------------------Images in articles------------------------------------")
    for i in reg.images:
        a = '\n\t' + i
    print(a)
    print()
    print("__________________________________Summary_______________________________________")
    summ = reg.summary
    print(summ)
    
    
#summary_extract("https://www.bbc.co.uk/news/business-58735299")
summary_extract(a[1])
# Out:
# ----Author Name-------- ['Tracey Tully']
#
# ----Publish Date-------= 2021-10-03 00:00:00
#
# -----------------------------------text-----------------------------------
# text of the article =  RIDGEWOOD, N.J. — On Election Day in 2018, Cathy Brienza opened her light blue colonial in a New Jersey suburb to dozens of Democratic activists for a get-out-the-vote rally. A freshman congressman, Josh Gottheimer, addressed a crowd filled with voters angered by Donald J. Trump’s presidency and hopeful of regaining Democratic control of the House.
#
# It worked. Fueled by a so-called blue wave, Democrats flipped four seats in New Jersey, re-elected Mr. Gottheimer and won the House.
#
# Now, as another midterm election looms, Ms. Brienza is again thinking about Mr. Gottheimer. But this time she is disappointed — and scared.
#
# ...

# %% [markdown]
# #### Saving the summmary in one format

# %%
complete = []
for news in a:
    so = Article(news)
    so.download()
    so.parse()
    so.download('punkt')
    so.nlp()
    print()
    print()
    print("url = ",news)
    print("--------------------------- Authors of the urls ------------------------ ")
    print(str(so.authors))
    print("Publish Date=",so.publish_date)
    print("---------------------------- Summary -------------------------------------- ")
    summary = so.summary
    print(summary)
    complete.append(summary)
# Out:
# url =  https://www.nytimes.com/2021/10/03/us/politics/supreme-court-new-term.html
# --------------------------- Authors of the urls ------------------------
# ['Adam Liptak']
# Publish Date= 2021-10-03 00:00:00
# ---------------------------- Summary --------------------------------------
# WASHINGTON — A transformed Supreme Court returns to the bench on Monday to start a momentous term in which it will consider eliminating the constitutional right to abortion, vastly expanding gun rights and further chipping away at the wall separating church and state.
# The abortion case, a challenge to a Mississippi law that bars most abortions after 15 weeks, has attracted the most attention.
# The highly charged docket will test the leadership of Chief Justice John G. Roberts Jr., who lost his position at the court’s ideological center with the arrival last fall of Justice Amy Coney Barrett.
# ...

# %%
complete
# Out:
# ['WASHINGTON — A transformed Supreme Court returns to the bench on Monday to start a momentous term in which it will consider eliminating the constitutional right to abortion, vastly expanding gun rights and further chipping away at the wall separating church and state.\nThe abortion case, a challenge to a Mississippi law that bars most abortions after 15 weeks, has attracted the most attention.\nThe highly charged docket will test the leadership of Chief Justice John G. Roberts Jr., who lost his position at the court’s ideological center with the arrival last fall of Justice Amy Coney Barrett.\nHe is now outflanked by five justices to his right, limiting his ability to guide the court toward the consensus and incrementalism he has said he prefers.\nThe chief justice, who views himself as the custodian of the court’s institutional authority, now leads a court increasingly associated with partisanship and that recent polls show is suffering a distinct drop in public support.',
# ...

# %% [markdown]
# ### Testing Gap for two Article Summaries

# %%
b = []
for i in range(2):
    so = Article(a[i])
    so.download()
    so.parse()
    so.download('punkt')
    so.nlp()
    print()
    print("------summary-------")
    print(so.summary)
    b.append(so.summary)
    print()
# Out:
# ------summary-------
# WASHINGTON — A transformed Supreme Court returns to the bench on Monday to start a momentous term in which it will consider eliminating the constitutional right to abortion, vastly expanding gun rights and further chipping away at the wall separating church and state.
# The abortion case, a challenge to a Mississippi law that bars most abortions after 15 weeks, has attracted the most attention.
# The highly charged docket will test the leadership of Chief Justice John G. Roberts Jr., who lost his position at the court’s ideological center with the arrival last fall of Justice Amy Coney Barrett.
# He is now outflanked by five justices to his right, limiting his ability to guide the court toward the consensus and incrementalism he has said he prefers.
# ...

# %%
len(b)
# Out:
# 2

# %%
b[1]
# Out:
# 'RIDGEWOOD, N.J. — On Election Day in 2018, Cathy Brienza opened her light blue colonial in a New Jersey suburb to dozens of Democratic activists for a get-out-the-vote rally.\nA freshman congressman, Josh Gottheimer, addressed a crowd filled with voters angered by Donald J. Trump’s presidency and hopeful of regaining Democratic control of the House.\nFueled by a so-called blue wave, Democrats flipped four seats in New Jersey, re-elected Mr. Gottheimer and won the House.\nNow, as another midterm election looms, Ms. Brienza is again thinking about Mr. Gottheimer.\n“He is undermining President Biden’s agenda,” said Ms. Brienza, 62, the founder of Ridgewood JOLT, which grew after the 2017 Women’s March into a 1,400-member political organizing group based in Ridgewood, N.J.'

# %% [markdown]
# ### Cleaning Process

# %%
len(a)
# Out:
# 70

# %%
len(complete)
# Out:
# 70

# %%
complete[14]
# Out:
# 'She “is a very courageous person and is taking a personal risk to hold a trillion-dollar company accountable,” he said.\nOn Sunday, Frances Haugen revealed herself to be “Sean,” the whistle-blower against Facebook.\nIn an interview with “60 Minutes” that aired Sunday, Ms. Haugen, 37, said she had grown alarmed by what she saw at Facebook.\n“I’ve seen a bunch of social networks and it was substantially worse at Facebook than what I had seen before,” Ms. Haugen said.\nThe revelations — including that Facebook knew Instagram was worsening body image issues among teenagers and that it had a two-tier justice system — have spurred criticism from lawmakers, regulators and the public.'

# %% [markdown]
# ### importing packages

# %%
import nltk

# %%
from nltk.stem import PorterStemmer , WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\korla\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stemming_var = PorterStemmer()
lemma = WordNetLemmatizer()

# %% [markdown]
# ### List of stopwords

# %%
print(stopwords.words("english"))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
stop = stopwords.words("english")
len(stop)
# Out:
# 179

# %%
import re

# %% [markdown]
# ### Cleaning data for one Article

# %%
cleaned_data = []
for k in range(1):
    review = re.sub('http\S+\s*', ' ', complete[k])  # remove URLs
    review = re.sub('RT|cc', '', review)  # remove RT and cc
    review = re.sub('#\S+', ' ', review)  # remove hashtags
    review = re.sub('@\S+', ' ', review)  # remove mentions
    review = re.sub('[%s]' % re.escape("""!"#$%&'()*+-,./:;<=>?@[\]^_`{|}~"""), '', review)  # remove punctuations
    review = re.sub(r'[^\x00-\x7f]',r' ', review) 
    review = re.sub('\s+', ' ', review)  # remove extra whitespace
    review = review.lower()
    review = review.split()
    #review = [lemma.lemmatize(word) for word in review if not word in stopwords.words("english")]
    review = ' '.join(review)
    cleaned_data.append(review)

# %%
cleaned_data
# Out:
# ['washington a transformed supreme court returns to the bench on monday to start a momentous term in which it will consider eliminating the constitutional right to abortion vastly expanding gun rights and further chipping away at the wall separating church and state the abortion case a challenge to a mississippi law that bars most abortions after 15 weeks has attracted the most attention the highly charged docket will test the leadership of chief justice john g roberts jr who lost his position at the court s ideological center with the arrival last fall of justice amy coney barrett he is now outflanked by five justices to his right limiting his ability to guide the court toward the consensus and incrementalism he has said he prefers the chief justice who views himself as the custodian of the court s institutional authority now leads a court increasingly associated with partisanship and that recent polls show is suffering a distinct drop in public support']

# %%
complete[0]
# Out:
# 'WASHINGTON — A transformed Supreme Court returns to the bench on Monday to start a momentous term in which it will consider eliminating the constitutional right to abortion, vastly expanding gun rights and further chipping away at the wall separating church and state.\nThe abortion case, a challenge to a Mississippi law that bars most abortions after 15 weeks, has attracted the most attention.\nThe highly charged docket will test the leadership of Chief Justice John G. Roberts Jr., who lost his position at the court’s ideological center with the arrival last fall of Justice Amy Coney Barrett.\nHe is now outflanked by five justices to his right, limiting his ability to guide the court toward the consensus and incrementalism he has said he prefers.\nThe chief justice, who views himself as the custodian of the court’s institutional authority, now leads a court increasingly associated with partisanship and that recent polls show is suffering a distinct drop in public support.'

# %% [markdown]
# #### Complete data cleaning

# %%
cleaned_data = []
for k in range(len(complete)):
    review = re.sub('http\S+\s*', ' ', complete[k])  # remove URLs
    review = re.sub('RT|cc', '', review)  # remove RT and cc
    review = re.sub('#\S+', ' ', review)  # remove hashtags
    review = re.sub('@\S+', ' ', review)  # remove mentions
    review = re.sub('[%s]' % re.escape("""!"#$%&'()*+-,./:;<=>?@[\]^_`{|}~"""), '', review)  # remove punctuations
    review = re.sub(r'[^\x00-\x7f]',r' ', review) 
    review = re.sub('\s+', ' ', review)  # remove extra whitespace
    review = review.lower()
    review = review.split()
    #review = [lemma.lemmatize(word) for word in review if not word in stopwords.words("english")]
    review = ' '.join(review)
    cleaned_data.append(review)

# %%
cleaned_data
# Out:
# ['washington a transformed supreme court returns to the bench on monday to start a momentous term in which it will consider eliminating the constitutional right to abortion vastly expanding gun rights and further chipping away at the wall separating church and state the abortion case a challenge to a mississippi law that bars most abortions after 15 weeks has attracted the most attention the highly charged docket will test the leadership of chief justice john g roberts jr who lost his position at the court s ideological center with the arrival last fall of justice amy coney barrett he is now outflanked by five justices to his right limiting his ability to guide the court toward the consensus and incrementalism he has said he prefers the chief justice who views himself as the custodian of the court s institutional authority now leads a court increasingly associated with partisanship and that recent polls show is suffering a distinct drop in public support',
# ...

# %%
cleaned_data[17]
# Out:
# 'then i learned about elizabeth holmes a rare female paragon of supersuessful genius with her health technology company theranos she was crowned america s youngest selfmade female billionaire by 2014 i couldn t tell if i was putting limits on myself or if this was just the way it was although it feels somewhat shameful to admit now i was a little jealous of what ms holmes had achieved she came off as intellectual and nerdy unlike the sleek instagramfiltered girl bosses with their marketing shticks'

# %%
complete[17]
# Out:
# 'Then I learned about Elizabeth Holmes, a rare female paragon of super-successful genius.\nWith her health technology company, Theranos, she was crowned America’s youngest self-made female billionaire by 2014.\nI couldn’t tell if I was putting limits on myself, or if this was just the way it was.\nAlthough it feels somewhat shameful to admit now, I was a little jealous of what Ms. Holmes had achieved.\nShe came off as intellectual and nerdy, unlike the sleek Instagram-filtered “girl bosses” with their marketing shticks.'

# %% [markdown]
# ### Comparing cleaned summary and Article summary

# %%
print(len(a))
print(len(cleaned_data))
# Out:
# 70
# 70

# %%
total = []
for news in range(len(a)):
    so = Article(a[news])
    so.download()
    so.parse()
    so.download('punkt')
    so.nlp()
    print()
    print()
    print("url = ",a[news])
    print()
    print("Authors = " , str(so.authors))
    print("Publish Date=",so.publish_date)
    print("---------------------------- Summary -------------------------------------- ")
    summary = so.summary
    print(summary)
    print()
    print("-------------------------data cleaned summary-----------------")
    print(cleaned_data[news])
    complete.append(summary)
# Out:
# url =  https://www.nytimes.com/2021/10/03/us/politics/supreme-court-new-term.html
#
# Authors =  ['Adam Liptak']
# Publish Date= 2021-10-03 00:00:00
# ---------------------------- Summary --------------------------------------
# WASHINGTON — A transformed Supreme Court returns to the bench on Monday to start a momentous term in which it will consider eliminating the constitutional right to abortion, vastly expanding gun rights and further chipping away at the wall separating church and state.
# The abortion case, a challenge to a Mississippi law that bars most abortions after 15 weeks, has attracted the most attention.
# The highly charged docket will test the leadership of Chief Justice John G. Roberts Jr., who lost his position at the court’s ideological center with the arrival last fall of Justice Amy Coney Barrett.
# He is now outflanked by five justices to his right, limiting his ability to guide the court toward the consensus and incrementalism he has said he prefers.
# ...

# %% [markdown]
# ### Testing the data For any Article URL

# %%
output = []
def output_data(url):
        so = Article(url)
        so.download()
        so.parse()
        so.download('punkt')
        so.nlp()
        print()
        print()
        print("url = ",url)
        print()
        print("Authors = " , str(so.authors))
        print("Publish Date=",so.publish_date)
        print("---------------------------- Summary -------------------------------------- ")
        summary = so.summary
        print(summary)
        print()
        review = re.sub('http\S+\s*', ' ', summary)  # remove URLs
        review = re.sub('RT|cc', '', review)  # remove RT and cc
        review = re.sub('#\S+', ' ', review)  # remove hashtags
        review = re.sub('@\S+', ' ', review)  # remove mentions
        review = re.sub('[%s]' % re.escape("""!"#%&'()*+,/;<=>?@[\]^_`{|}~”“"""), '', review)  # remove punctuations
       # review = re.sub(r'[^\x00-\x7f]',r' ', review) 
        review = re.sub('\s+', ' ', review)  # remove extra whitespace
       # review = review.lower()
        review = review.split()
        #review = [lemma.lemmatize(word) for word in review if not word in stopwords.words("english")]
        review = ' '.join(review)
        output.append(review)
        
        print("------------------------- data cleaned summary -----------------")
        print()
        print(output)

# %%
url = 'https://timesofindia.indiatimes.com/business/india-business/air-travel-demand-recovers-to-60-of-pre-covid-levels/articleshow/86963363.cms'

# %%
output_data(url)
# Out:
# url =  https://timesofindia.indiatimes.com/business/india-business/air-travel-demand-recovers-to-60-of-pre-covid-levels/articleshow/86963363.cms
#
# Authors =  []
# Publish Date= None
# ---------------------------- Summary --------------------------------------
# NEW DELHI: The demand for air travel is finally picking up thanks to the festival season, and after the government allowed airlines to operate up to 85% of their pre-Covid capacity domestically.Increase in vaccination and a dip in Covid infections has boosted travel sentiment too.
# The aim was to boost air traffic.Last month, the aviation ministry revised the caps and increased both the upper and the lower limit.
# "This may be underpinned by removal on airfare cap beyond 15 days, especially during seasonally peak demand quarter of the year.
# However, medium-term concerns – intensifying competition post any revival in Jet Airways and ramp-up in Indian Railways operations – exist.
# ...

# %% [markdown]
# ### Another logic for data cleaning part

# %%
output_1 = []
def output_data_1(url):
        so = Article(url)
        so.download()
        so.parse()
        so.download('punkt')
        so.nlp()
        print()
        print()
        print("url = ",url)
        print()
        print("Authors = " , str(so.authors))
        print("Publish Date=",so.publish_date)
        print("---------------------------- Summary -------------------------------------- ")
        summary = so.summary
        print(summary)
        print()
        result = re.sub("[^a-zA-Z0-9.$-’]",' ',summary)
       # result = result.lower()
        result = result.split()
        #result = [lemma.lemmatize(word)  for word in result if not word in stopwords.words("english")]
        result = ' '.join(result)
        output_1.append(result)
        print("-------------------------data cleaned summary-----------------")
        print()
        print(output_1)

# %%
url = 'https://www.nature.com/articles/d41586-021-02813-y'

# %%
output_data_1(url)
# Out:
# url =  https://www.nature.com/articles/d41586-021-02813-y
#
# Authors =  ['Maxmen', 'Amy Maxmen', 'You Can Also Search For This Author In']
# Publish Date= None
# ---------------------------- Summary --------------------------------------
# Shortcomings in that approach have become clear as the origin of the COVID-19 pandemic remains unknown nearly two years after it began.
# “Next time an outbreak is declared, the secretariat can pull this committee together,” she says, and ask for advice on what information researchers should collect immediately.
# Last month, Sachs disbanded a Lancet commission team assessing pandemic origins out of frustration with a lack of transparency from its members.
# Once the panel is confirmed, the group will take stock of what’s already known about the origins of COVID-19, and outline next steps.
# But Van Kerkove expects collaboration from the country, and is hopeful the focus will be on science rather than geopolitics.
#
# ...
